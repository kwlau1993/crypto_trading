# %%
import requests
import csv
import pandas as pd
import json
import datetime
import matplotlib.pyplot as plt
# add what coins you want to fetch data for
coin_list = ["BTC"]
# "ETH", "BCH", "EOS", "LTC", "XLM", "XRP", "NEO", "BNB", "NCASH", "TRAC", "DASH", "XEM", "XRM"]
#add what markets you want the coins to be correlated with
unit = "USDT"
#add whatever data u would like to download, check API documentation
time = [ "histoday" ]
#add exchanges
#exchange_list = ["HuobiPro", "OKEx", "HitBTC", "Binance", "CCCAGG", "Kraken"]
exchange_list = ["CCCAGG"]
#crypto_compare_api_key: 3572069bc364dff0fef949ebb4b4dd8035adee786703c33a2a792d0069c29901
#https://min-api.cryptocompare.com/data/ob/l2/snapshot?fsym=ETH&tsym=BTC&e=Binance&limit=-1&api_key={your_api_key}
limit = 324

# %%
#my_key = '3572069bc364dff0fef949ebb4b4dd8035adee786703c33a2a792d0069c29901'

now = datetime.datetime.now()
tdy_time = int(datetime.datetime.timestamp(now))

for j in time:
    for e in exchange_list:
        for c in coin_list: 
            rcomp = requests.get('https://min-api.cryptocompare.com/data/' + j + '?fsym='+ c +'&tsym=' + unit + '&limit=' + str(limit) +'&e=' + e +'&toTs=' + str(tdy_time)).json()
            response = rcomp['Data']
            crypto_data = pd.DataFrame(response)
            #crypto_data.to_csv('/Users/apple/Desktop/crypto_valuation/valuation_scripts/' + c +'-'+ unit + '_' + j + '_' + e + 'OD' + '.csv')
            
#rcomp = requests.get('https://min-api.cryptocompare.com/data/v2/all/exchanges?fsym=BTC').json()
#response = rcomp['Data']
#crypto_data = pd.DataFrame(response)
#print pd.DataFrame.transpose(crypto_data)
#crypto_data.to_csv('/Users/apple/Desktop/crypto_valuation/valuation_scripts/Exchange_Info_full.csv')

# %%
for i in range(0,limit+1):
    crypto_data['time'][i] = datetime.datetime.fromtimestamp(crypto_data['time'][i])
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
crypto_data
# Out:
#        close      high      low     open                 time  volumefrom  \
# 0    3797.48   3802.70  3648.70  3701.45  2019-01-01 01:00:00   168823.74
# 1    3860.63   3883.40  3756.09  3797.48  2019-01-02 01:00:00   232437.26
# 2    3766.14   3863.07  3735.22  3860.63  2019-01-03 01:00:00   158574.41
# 3    3792.34   3820.40  3706.77  3766.14  2019-01-04 01:00:00   199654.16
# 4    3773.52   3837.14  3756.14  3792.34  2019-01-05 01:00:00   182654.73
# 5    3990.20   4021.86  3748.86  3773.52  2019-01-06 01:00:00   191724.03
# 6    3977.32   4014.99  3931.30  3990.20  2019-01-07 01:00:00   198001.32
# 7    3956.80   4057.20  3932.20  3977.32  2019-01-08 01:00:00   198454.38
# 8    3965.31   4002.04  3944.61  3956.80  2019-01-09 01:00:00   194995.64
# 9    3587.51   3994.13  3546.43  3965.31  2019-01-10 01:00:00   279155.86
# 10   3605.68   3647.16  3544.15  3587.51  2019-01-11 01:00:00   225466.42
# 11   3586.24   3619.41  3549.58  3605.68  2019-01-12 01:00:00   168921.90
# ...

# %%
#tdy's volume in BTC
print('The 24 hr volume of today: ' + str(crypto_data['volumefrom'][limit]))
print('The 24 hr volume of yesterday: ' + str(crypto_data['volumefrom'][limit-1]))
# Out:
# The 24 hr volume of today: 91522.04
# The 24 hr volume of yesterday: 288726.22

# %%
crypto_data['volumefrom'].describe()
# Out:
# count       325.000000
# mean     271359.413631
# std       97652.357029
# min       91522.040000
# 25%      200935.580000
# 50%      254055.380000
# 75%      320328.420000
# max      791865.130000
# Name: volumefrom, dtype: float64

# %%
crypto_data['volumefrom'].median()
# Out:
# 254055.38

# %%
plt.plot(crypto_data['volumefrom'])
